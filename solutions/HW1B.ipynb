# %% [markdown]
# ### A. Compute the following probabilities and state what type of probability (marginal, joint, conditional)
# ```
# 1. P(x = love | y = ham) = 2/3, conditional probability
#
# 2. P(y = spam) = 2/5, marginal probability
#
# 3. P(x = bargains) = 2/5, marginal probability
#
# 4. P(y = ham | x = "You love bargains")
#     = P(x = "You love bargains" | y = ham) * P(y = ham) / P(x = "You love bargains"), where
#   * P(x = "You love bargains" | y = ham)
#     = P(x = "You" | y = ham) * P(x = "love" | y = ham) * P(x = "bargains" | y = ham) = 1/3 * 2/3 * 0 = 0
#   * P(y = ham) = 3/5
#   * P(x = "You love bargains")
#     = P(x = "You love bargains" | y = ham) * P(y = ham) + P(x = "You love bargains" | y = spam) * P(y = spam)
#     = 0 + P(x = "You" | y = spam) * P(x = "love" | y = spam) * P(x = "bargains" | y = spam) * P(y = spam)
#     = 0+ 1/2 * 1/2 * 1 * 2/5 = 1/10
#    Therefore, P(y = ham | x = "You love bargains") = (0 * 3/5) / (1/10) = 0, conditional probability
#
# ```

# %% [markdown]
# ### B. Former In-Class Exercise Word Count

# %% [markdown]
# #### To answer marketing manager's questions:
#
# The first assumption is that the customer segment (sons, significant others, grandchildren, siblings, self, etc.) appeared in the reviews indicates who the toy was bought for.
#
# * From the result of unique word count, we can see that "daughter and daughters" together occurred 6381 times, "son and sons" together occurred 6224 times, "grandson and grandsons" together occurred 3485 times in positive reviews. So, for positive reviews, the top 3 most frequently appeared customer segments are daughter, son, and grandson.
#
#      For negative reviews, "son and sons" together occurred 559 times, "daughter and daughters" together occurred 371 times,  "grandson and grandsons" together occurred 145 times. So, for negative reviews, the top 3 most frequently appeared customer segments are son, daughter and grandson.
#
#     You can also see the bar graphs in the python code below to have a more detailed customer segments information and how many times they appeared in reviews (Bar graphs are in the "Word Count for Positive Reviews" and "Word Count for Negative Reviews" sections).
#
#
# * To analyze which customer segments' marketing messaging tends to outperform other segments, I considered the following factors:
#
#     1. Customer segment word count in positive reviews, which shows how many likes from each customer segment
#     2. Customer segment word count in negative reviews, which shows how many dislikes from each customer segment
#     3. Review star (5 star for positive and 1 star for negative), which indicates level of satisfaction for each customer segment
#
#     We could not just consider the word count in positive or negative reviews individually, because the cutomer segment that has the most positive reviews may also has the most negative reviews. In this case, we cannot say this customer segment outperforms or falls behind the others.
#
#     However, if we assumed that for each customer segment, the number of word counts is equal to the number of reviews and can somewhat represent the quantity of sales, then we can use the sum of word counts in both positive and negative reviews to evaluate sales for each customer segment. The larger the sum, the more toys were sold to the corresponding customer segment. Result for this approach is shown below:
#     ```
#      {'daughter': 6752,
#  'granddaughter': 2488,
#  'grandson': 3630,
#  'nephew': 1171,
#  'niece': 1030,
#  'self': 127,
#  'sibling': 886,
#  'son': 6783}
#     ```
#     From the result, we can see that sales for "son" and "daughter" are far above the others. Therefore, according to this "sales" approach, I would conclude that son and daughter are the customer segments whose marketing messaging tend to outperform other segments.
#
#     What if the sales are high but reviews are poor? To solve this problem, we need to consider customer's level of satisfaction. To be specific, I want to see the average review star for each customer segment. Based on that, I made the following assumption: for each customer segment, the number of word counts is equal to the number of reviews.
#
#     Then, I calculated the average review star for each customer segment. For example, "son" counts 6224 in positive reviews and 559 in negative reviews. Given 5 star for a positive review and 1 star for a negative review, the average review star for son is (5 x 6224 + 1 x 559) / (6224 + 559) = 4.67
#
#     According to the average review star calculation method above, the result for each customer segment is shown below:
#     ```
#     {'daughter': 4.78,
#  'granddaughter': 4.887,
#  'grandson': 4.84,
#  'nephew': 4.891,
#  'niece': 4.864,
#  'self': 4.37,
#  'sibling': 4.828,
#  'son': 4.67}
#  ```
#     From the result of average review star, we can see that nephew has the highest average review star, granddaughter ranks the second. Therefore, according to this evaluation approach, I would conclude that nephew and granddaughter are the customer segments whose marketing messaging tend to outperform other segments.
#
#     However, the average star approach cares more about level of satisfaction than about quantity of sales. Therefore, there is a trade-off between sales and level of satisfaction in this case. Which customer segment performs better depends on the goal of marketing. If the goal is to sell more, then the "sales" approach applies. If the goal is to have better reputation, then the "average star" approach applies. If the goal is both of them, then I would recommend to combine the marketing strategy for son and daughter (large sales volume) with the marketing strategy for nephew and granddaughter (better reputation).

# %% [markdown]
# #### To answer product manager's question:
#    * I would reject the hypothesis. To explain why, I need to make the following assumptions firstly:
#        1. Count of "battery" and "batteries" equals the number of reviews that mention "battery" and "batteries" (keywords appear only once per review);
#        2. Reviews that mention "battery" or "batteries" are belong to toys with battery;
#        3. For the rest reviews that do not mention "battery" or "batteries", there is a certain percentage of reviews ("battery_per") belong to toys with battery. The percentage is the same for both positive and negative reviews;
#        4. If the average review for toys with battery is lower than 95% of the average review for toys without battery, then they have significant difference.
#
#     Based on the above assumptions, I tried different percentages ("battery_per") and interestingly found out that the average reviews for toys without battery were constant, which is 4.57. The average reviews for toys with battery kept increasing as percentage increased but they never exceeded 4.57.
#
#     To make it more straightforward, I plot the average reviews for toys with and without battery based on different percentages ("battery_per"), which is in the code below ("Battery" section). I also plot out the threshold line (the green dashed line), where the part below means that toys with batteries tend to be significantly lower rated than toys that do not require batteries, while the part above does not indicate the statement above.
#
#     As a result, we can see that if the threshold is 4.57 * 95% = 4.34, the percentage ("battery_per") is about 3%, meaning that if the hypothesis is true, then for the reviews that do not mention battery, there should be no more than 3% of them belong to toys with battery and no less than 97% belong to toys without battery. This could be possible but seems not to be realistic. I believe there is a larger probability that for the reviews that do not mention battery, there are more than 3% of them belong to toys with battery and less than 97% belong to toys without battery. If it is the case, then the toys with batteries do not tend to be significantly lower rated than toys that do not require batteries. Therefore, I would reject the hypothesis.

# %% [markdown]
# ## Below are the python code and comments for question B

# %% [markdown]
# ### Word Count for Positive Reviews

# %%
# Import positive reviews
pos_review = open("good_amazon_toy_reviews.txt", "r")

# %%
# read lines
pos_review.seek(0)
lines = pos_review.readlines()

# %%
# count unique words
from collections import Counter

def word_counts(lines, delimiter):
    words = Counter()
    
    for line in lines:
        line = line.lower()
        for word in line.split(delimiter):
            words[word] += 1
    
    return words

# %%
pos_toy_word_counts = word_counts(lines, " ")

# %%
# sort words and counts in a descending order
import operator
sorted(pos_toy_word_counts.items(), key=operator.itemgetter(1), reverse = True)
# Out:
# [('the', 111394),
#  ('and', 88165),
#  ('a', 68776),
#  ('to', 63788),
#  ('it', 51931),
#  ('i', 50472),
#  ('for', 49173),
#  ('', 44934),
#  ('is', 42613),
#  ('my', 42580),
#  ('this', 40908),
#  ('of', 36859),
#  ('with', 29257),
#  ('in', 26222),
#  ('great', 20971),
#  ('was', 20602),
#  ('are', 18750),
#  ('that', 18564),
#  ('as', 18051),
#  ('on', 18033),
#  ('so', 17204),
#  ('very', 16361),
#  ('love', 15951),
#  ('but', 15885),
#  ('you', 15455),
#  ('they', 14953),
#  ('have', 14655),
#  ('loves', 13407),
#  ('we', 10654),
#  ('he', 10451),
#  ('all', 9967),
#  ('not', 9915),
#  ('these', 9836),
#  ('just', 9765),
#  ('one', 9762),
#  ('be', 9703),
#  ('she', 9668),
#  ('little', 9345),
#  ('can', 8879),
#  ('old', 8858),
#  ('at', 8726),
#  ('like', 8634),
#  ("it's", 8214),
#  ('them', 8148),
#  ('loved', 8019),
#  ('good', 8017),
#  ('has', 7938),
#  ('her', 7831),
#  ('/><br', 7715),
#  ('will', 7702),
#  ('year', 7643),
#  ('fun', 7449),
#  ('or', 7223),
#  ('really', 7210),
#  ('when', 7066),
#  ('kids', 7046),
#  ('up', 6882),
#  ('had', 6488),
#  ('would', 6410),
#  ('well', 6282),
#  ('from', 6197),
#  ('get', 6187),
#  ('if', 5971),
#  ('son', 5869),
#  ('daughter', 5821),
#  ('out', 5811),
#  ('his', 5782),
#  ('play', 5698),
#  ('it.', 5681),
#  ('game', 5673),
#  ('more', 5634),
#  ('perfect', 5632),
#  ('than', 5575),
#  ('bought', 5502),
#  ('an', 5494),
#  ('our', 5271),
#  ('easy', 5088),
#  ('what', 5015),
#  ('got', 4795),
#  ('were', 4742),
#  ('nice', 4614),
#  ('your', 4482),
#  ('much', 4390),
#  ('about', 4345),
#  ('other', 4231),
#  ('some', 4184),
#  ('also', 4070),
#  ('no', 4031),
#  ('time', 4027),
#  ('quality', 3981),
#  ('set', 3969),
#  ('even', 3955),
#  ('only', 3904),
#  ('made', 3897),
#  ('use', 3886),
#  ('toy', 3863),
#  ('there', 3705),
#  ('product', 3692),
#  ('put', 3631),
#  ('"i', 3462),
#  ('do', 3408),
#  ('cute', 3400),
#  ('which', 3392),
#  ('gift', 3371),
#  ('by', 3371),
#  ('any', 3317),
#  ('2', 3306),
#  ('because', 3298),
#  ('their', 3281),
#  ('still', 3273),
#  ('make', 3260),
#  ('how', 3237),
#  ('grandson', 3178),
#  ('playing', 3146),
#  ('who', 3134),
#  ('-', 3125),
#  ('"this', 3094),
#  ('recommend', 3009),
#  ('me', 2964),
#  ('buy', 2943),
#  ('3', 2898),
#  ('it\n', 2897),
#  ('two', 2865),
#  ('came', 2836),
#  ('its', 2823),
#  ("don't", 2748),
#  ('first', 2693),
#  ('happy', 2693),
#  ('looks', 2685),
#  ('been', 2679),
#  ('"my', 2673),
#  ('over', 2655),
#  ('birthday', 2636),
#  ('it.\n', 2612),
#  ('am', 2577),
#  ('best', 2567),
#  ('used', 2552),
#  ('price', 2549),
#  ('lot', 2537),
#  ('into', 2500),
#  ("i'm", 2497),
#  ('big', 2488),
#  ('small', 2458),
#  ('size', 2441),
#  ('him', 2429),
#  ('super', 2404),
#  ('received', 2345),
#  ('too', 2314),
#  ('fast', 2288),
#  ('go', 2278),
#  ('around', 2260),
#  ('pretty', 2260),
#  ('after', 2259),
#  ('now', 2248),
#  ('many', 2242),
#  ('then', 2221),
#  ('granddaughter', 2184),
#  ('new', 2175),
#  ('works', 2166),
#  ('back', 2155),
#  ('definitely', 2151),
#  ('it!\n', 2139),
#  ('different', 2131),
#  ('enough', 2126),
#  ('arrived', 2112),
#  ('could', 2111),
#  ('few', 2097),
#  ('awesome', 2093),
#  ('4', 2087),
#  ('exactly', 2082),
#  ('off', 2082),
#  ('comes', 2069),
#  ('every', 2058),
#  ('take', 2041),
#  ('think', 2041),
#  ('each', 2033),
#  ('way', 2029),
#  ('see', 2027),
#  ('5', 2026),
#  ('look', 2004),
#  ('cards', 1991),
#  ('fit', 1987),
#  ('absolutely', 1978),
#  ('pieces', 1975),
#  ('makes', 1950),
#  ('box', 1941),
#  ('it,', 1919),
#  ('did', 1915),
#  ('does', 1913),
#  ('&', 1909),
#  ('keep', 1907),
#  ('thank', 1901),
#  ('excellent', 1901),
#  ('better', 1900),
#  ('it!', 1897),
#  ('looking', 1874),
#  ('worth', 1873),
#  ("can't", 1834),
#  ('purchased', 1799),
#  ('doll', 1792),
#  ('thing', 1774),
#  ('while', 1773),
#  ('need', 1758),
#  ('right', 1744),
#  ('since', 1738),
#  ('work', 1736),
#  ('most', 1730),
#  ('highly', 1728),
#  ('bit', 1726),
#  ('long', 1705),
#  ('figure', 1698),
#  ('want', 1696),
#  ('going', 1671),
#  ('find', 1656),
#  ('toys', 1650),
#  ('favorite', 1644),
#  ('come', 1642),
#  ('together', 1631),
#  ('them.', 1629),
#  ('both', 1628),
#  ('/>i', 1613),
#  ('sure', 1564),
#  ('item', 1563),
#  ("doesn't", 1554),
#  ('child', 1534),
#  ('"great', 1525),
#  ('years', 1520),
#  ('another', 1481),
#  ("i've", 1477),
#  ('colors', 1476),
#  ('know', 1474),
#  ('using', 1473),
#  ('able', 1469),
#  ('played', 1443),
#  ('always', 1440),
#  ('plastic', 1438),
#  ('everything', 1432),
#  ('card', 1416),
#  ('own', 1409),
#  ("didn't", 1395),
#  ('down', 1391),
#  ('being', 1386),
#  ('family', 1385),
#  ('/>the', 1384),
#  ('hard', 1377),
#  ('without', 1375),
#  ('lots', 1371),
#  ('baby', 1355),
#  ('high', 1351),
#  ('party', 1346),
#  ('actually', 1344),
#  ('6', 1334),
#  ('hours', 1331),
#  ('before', 1327),
#  ('say', 1313),
#  ('game.', 1295),
#  ('children', 1281),
#  ('same', 1281),
#  ('last', 1276),
#  ('thought', 1270),
#  ('great\n', 1269),
#  ('sturdy', 1265),
#  ('water', 1260),
#  ('cool', 1256),
#  ('never', 1253),
#  ('took', 1252),
#  ('things', 1249),
#  ('having', 1246),
#  ('getting', 1242),
#  ('easily', 1234),
#  ('beautiful', 1229),
#  ('give', 1219),
#  ('quite', 1213),
#  ('soft', 1210),
#  ('something', 1207),
#  ('color', 1200),
#  ('wanted', 1190),
#  ('where', 1189),
#  ('such', 1160),
#  ('ordered', 1156),
#  ('well.', 1142),
#  ('time.', 1139),
#  ('people', 1134),
#  ('worked', 1114),
#  ('kid', 1108),
#  ('real', 1105),
#  ('three', 1099),
#  ('addition', 1099),
#  ('fits', 1094),
#  ('friends', 1093),
#  ('purchase', 1090),
#  ('car', 1084),
#  ('hold', 1081),
#  ('through', 1077),
#  ('found', 1074),
#  ('amazing', 1074),
#  ('honest', 1070),
#  ('far', 1068),
#  ('light', 1063),
#  ('enjoy', 1062),
#  ('hit', 1061),
#  ('once', 1059),
#  ('seems', 1047),
#  ('ever', 1043),
#  ('large', 1036),
#  ('likes', 1029),
#  ('day', 1016),
#  ('puzzle', 1016),
#  ('month', 1015),
#  ('several', 1013),
#  ('plays', 1012),
#  ('part', 1008),
#  ('girl', 1006),
#  ('games', 1005),
#  ('great.', 1002),
#  ('nephew', 990),
#  ('it."\n', 989),
#  ('must', 986),
#  ('almost', 981),
#  ('this.', 971),
#  ('those', 968),
#  ('toy.', 963),
#  ('top', 960),
#  ('order', 946),
#  ('should', 944),
#  ('enjoyed', 941),
#  ('good\n', 937),
#  ('wish', 928),
#  ('extra', 925),
#  ('1', 924),
#  ('learning', 920),
#  ('help', 919),
#  ('add', 914),
#  ('batteries', 906),
#  ('everyone', 906),
#  ('exchange', 904),
#  ('months', 901),
#  ('especially', 895),
#  ('piece', 894),
#  ('ones', 892),
#  ('quality.', 892),
#  ('making', 890),
#  ('though', 882),
#  ('wait', 881),
#  ('10', 879),
#  ("that's", 877),
#  ('buying', 870),
#  ('product.', 869),
#  ('gave', 868),
#  ('8', 868),
#  ('huge', 866),
#  ('feel', 866),
#  ('gets', 866),
#  ('niece', 865),
#  ('review', 861),
#  ('battery', 858),
#  ('fun.', 853),
#  ('lego', 851),
#  ('house', 844),
#  ('excited', 841),
#  ('price.', 839),
#  ('christmas', 835),
#  ("you're", 833),
#  ("he's", 830),
#  ('couple', 824),
#  ('adorable', 818),
#  ('quick', 807),
#  ('us', 807),
#  ('7', 806),
#  ('learn', 805),
#  ('pleased', 804),
#  ('"these', 803),
#  ('grand', 803),
#  ('"the', 800),
#  ('takes', 799),
#  ('expected', 794),
#  ('smaller', 793),
#  ('next', 792),
#  ('may', 790),
#  ('needed', 787),
#  ('build', 785),
#  ('board', 782),
#  ('wonderful', 782),
#  ('already', 780),
#  ('simple', 779),
#  ('shipping', 775),
#  ('yr', 774),
#  ('birthday.', 773),
#  ('kit', 769),
#  ('anyone', 767),
#  ('set.', 760),
#  ("they're", 759),
#  ('girls', 759),
#  ('young', 756),
#  ('quickly', 752),
#  ('durable', 750),
#  ('boys', 748),
#  ('fan', 747),
#  ('parts', 745),
#  ('try', 739),
#  ('times', 734),
#  ('again', 726),
#  ('probably', 726),
#  ('bag', 720),
#  ('inside', 718),
#  ('perfectly', 718),
#  ('went', 717),
#  ('glad', 710),
#  ('room', 709),
#  ('"very', 708),
#  ('might', 706),
#  ('hands', 701),
#  ('bigger', 700),
#  ('here', 699),
#  ('liked', 698),
#  ('full', 694),
#  ('detail', 693),
#  ('paint', 691),
#  ('along', 688),
#  ('keeps', 688),
#  ("she's", 687),
#  ('whole', 684),
#  ('cute.', 682),
#  ('sets', 680),
#  ('let', 676),
#  ('husband', 671),
#  ('amazon', 670),
#  ('free', 668),
#  ('building', 668),
#  ('open', 667),
#  ('"we', 666),
#  ('quality,', 662),
#  ('pool', 660),
#  ('second', 659),
#  ('figures', 659),
#  ('side', 656),
#  ('away', 656),
#  ('/>this', 654),
#  ('too.', 654),
#  ('looked', 651),
#  ('.', 650),
#  ('old.', 650),
#  ('putting', 650),
#  ('case', 647),
#  ('model', 645),
#  ('together.', 641),
#  ('goes', 640),
#  ('one.', 638),
#  ('game,', 637),
#  ('turn', 637),
#  ('said', 637),
#  ('older', 636),
#  ("isn't", 629),
#  ('held', 629),
#  ('hair', 629),
#  ('place', 626),
#  ('four', 625),
#  ('bright', 624),
#  ('picture', 623),
#  ('dolls', 622),
#  ('end', 620),
#  ('fly', 617),
#  ('saw', 617),
#  ('hand', 616),
#  ('stand', 615),
#  ('unbiased', 614),
#  ('days', 606),
#  ('black', 606),
#  ("couldn't", 606),
#  ('version', 604),
#  ('less', 603),
#  (':)\n', 603),
#  ('yet', 601),
#  ('seem', 600),
#  ('up.', 599),
#  ("won't", 594),
#  ('head', 592),
#  ('original', 592),
#  ('larger', 591),
#  ('age', 588),
#  ('anything', 588),
#  ('seen', 587),
#  ('lights', 587),
#  ('dress', 587),
#  ("son's", 585),
#  ('product\n', 585),
#  ('nicely', 584),
#  ('them.\n', 583),
#  ('trying', 579),
#  ('minutes', 578),
#  (',', 577),
#  ('fine', 574),
#  ("haven't", 573),
#  ('until', 567),
#  ('under', 566),
#  ('start', 566),
#  ('table', 566),
#  ('boy', 563),
#  ('great!', 562),
#  ('ball', 562),
#  ('school', 560),
#  ('daughters', 560),
#  ('store', 559),
#  ('read', 559),
#  ('front', 559),
#  ('included', 558),
#  ('move', 556),
#  ('these.', 555),
#  ('instructions', 555),
#  ('friend', 555),
#  ('toddler', 554),
#  ('great,', 553),
#  ('extremely', 552),
#  ('face', 544),
#  ('during', 543),
#  ("wasn't", 542),
#  ('them,', 532),
#  ('great!\n', 532),
#  ('cars', 529),
#  ('collection', 527),
#  ('red', 525),
#  ('bad', 524),
#  ('cheap', 524),
#  ('discount', 523),
#  ('"bought', 523),
#  ('deck', 522),
#  ('flying', 522),
#  ('pop', 521),
#  ('ages', 521),
#  ('started', 521),
#  ('"love', 518),
#  ('9', 517),
#  ('plush', 516),
#  ('made.', 516),
#  ('white', 515),
#  ('however,', 515),
#  ('well,', 515),
#  ('items', 511),
#  ('star', 511),
#  ('adults', 511),
#  ('blue', 511),
#  ('pack', 509),
#  ('holds', 509),
#  ('action', 508),
#  ('expected.', 507),
#  ('cute!', 507),
#  ('problem', 507),
#  ('doing', 506),
#  ('product,', 506),
#  ('five', 505),
#  ('it!"\n', 503),
#  ('enjoys', 503),
#  ('kind', 500),
#  ('book', 500),
#  ('money', 499),
#  ('fantastic', 499),
#  ('delivered', 499),
#  ('overall', 494),
#  ('working', 492),
#  ('heavy', 491),
#  ('delivery', 490),
#  ('play.', 489),
#  ('design', 489),
#  ('party.', 487),
#  ('nothing', 487),
#  ('others', 484),
#  ('fun,', 484),
#  ("daughter's", 484),
#  ('night', 483),
#  ('out.', 482),
#  ('present', 479),
#  ('brand', 479),
#  ('time,', 479),
#  ('done', 478),
#  ('least', 476),
#  ('wear', 471),
#  ('run', 469),
#  ('reviews', 469),
#  ('mine', 468),
#  ('train', 468),
#  ('video', 468),
#  ('built', 466),
#  ('watch', 466),
#  ('plus', 463),
#  ('home', 460),
#  ('price,', 460),
#  ('uses', 458),
#  ('instead', 457),
#  ('material', 457),
#  ('package', 456),
#  ('stuffed', 455),
#  ('pull', 454),
#  ('younger', 452),
#  ('seller', 452),
#  ('bottom', 452),
#  ('someone', 451),
#  ('thanks', 451),
#  ('kept', 449),
#  ("i'd", 449),
#  ('break', 448),
#  ('turned', 448),
#  ('added', 448),
#  ('nice\n', 447),
#  ('grandkids', 447),
#  ('shipped', 446),
#  ('excellent\n', 446),
#  ('wants', 446),
#  ('although', 445),
#  ('helps', 444),
#  ('totally', 442),
#  ('adult', 442),
#  ('opened', 442),
#  ('pictures', 441),
#  ('says', 441),
#  ('balloons', 440),
#  ("we've", 439),
#  ('plenty', 439),
#  ('show', 438),
#  ('them\n', 438),
#  ('left', 438),
#  ('costume', 437),
#  ('amount', 437),
#  ('fact', 436),
#  ('this,', 436),
#  ('wheels', 436),
#  ('with.', 435),
#  ('gift.', 431),
#  ('strong', 431),
#  ('deal', 430),
#  ('tell', 430),
#  ('tried', 430),
#  ("i'll", 429),
#  ("there's", 428),
#  ('clear', 428),
#  ('kids.', 427),
#  ('stay', 426),
#  ('review.', 425),
#  ('surprised', 424),
#  ('sounds', 423),
#  ('this!', 423),
#  ('tiny', 423),
#  ('perfect\n', 423),
#  ('truck', 422),
#  ('guy', 421),
#  ('half', 420),
#  ('puzzles', 420),
#  ('control', 419),
#  ('perfect.', 419),
#  ('cute,', 418),
#  ('air', 418),
#  ('easier', 418),
#  ('holding', 417),
#  ('solid', 417),
#  ('blocks', 416),
#  ('between', 415),
#  ('fun!', 415),
#  ('sound', 415),
#  ('difficult', 415),
#  ('you\n', 414),
#  ('taking', 412),
#  ('needs', 411),
#  ('/>-', 411),
#  ('game!', 410),
#  ('power', 410),
#  ('sit', 409),
#  ('awesome\n', 409),
#  ('itself', 408),
#  ('cute\n', 406),
#  ('life', 406),
#  ('detailed', 405),
#  ('change', 404),
#  ('nerf', 404),
#  ('described.', 403),
#  ('toy,', 403),
#  ('stuff', 403),
#  ('given', 400),
#  ('motor', 400),
#  ('green', 399),
#  ('weight', 398),
#  ('stickers', 397),
#  ('review."\n', 396),
#  ('clean', 396),
#  ('box.', 395),
#  ('number', 395),
#  ('/>it', 395),
#  ('expect', 394),
#  ('sand', 394),
#  ('value', 393),
#  ("wouldn't", 392),
#  ('outside', 391),
#  ('up,', 391),
#  ('players', 388),
#  ('eyes', 387),
#  ('use.', 387),
#  ('variety', 386),
#  ('track', 385),
#  ("you'll", 385),
#  ('handle', 385),
#  ('hope', 385),
#  ('player', 384),
#  ('longer', 383),
#  ('why', 382),
#  ('mini', 379),
#  ("aren't", 378),
#  ('him.', 378),
#  ('condition.', 377),
#  ('expansion', 377),
#  ('decided', 376),
#  ('blast', 376),
#  ('12', 376),
#  ('doll.', 376),
#  ('thanks\n', 375),
#  ('type', 375),
#  ('maybe', 374),
#  ('fairly', 374),
#  ('pick', 372),
#  ('awesome.', 372),
#  ('fall', 371),
#  ('push', 371),
#  ('product.\n', 369),
#  ('american', 369),
#  ('balls', 368),
#  ('simply', 368),
#  ('pink', 368),
#  ('stick', 367),
#  ('impressed', 366),
#  ('special', 366),
#  ('hot', 365),
#  ('characters', 365),
#  ('feels', 365),
#  ('complete', 365),
#  ('!\n', 364),
#  ('low', 364),
#  ('rather', 362),
#  ('watching', 361),
#  ('you!\n', 360),
#  ('toy!', 360),
#  ('lost', 360),
#  ('(and', 360),
#  ('completely', 359),
#  ('person', 356),
#  ('on.', 356),
#  ('animals', 356),
#  ('condition', 355),
#  ('her.', 355),
#  ('sons', 355),
#  ('ready', 354),
#  ('well.\n', 354),
#  ('thrilled', 354),
#  ('sister', 354),
#  ('finally', 354),
#  ('"a', 354),
#  ('cards.', 353),
#  ('carry', 353),
#  ('line', 353),
#  ('--', 353),
#  ('packaged', 352),
#  ('soon', 352),
#  ('dice', 352),
#  ('idea', 352),
#  ('button', 352),
#  ('mom', 351),
#  ('dog', 351),
#  ('made,', 350),
#  ('charge', 349),
#  ('cute!\n', 349),
#  ('feet', 349),
#  ('summer', 348),
#  ('paper', 346),
#  ('sometimes', 346),
#  ('bring', 346),
#  ('grandchildren', 345),
#  ('animal', 344),
#  ('gun', 344),
#  ('details', 344),
#  ('hang', 343),
#  ('them!\n', 343),
#  ('forward', 343),
#  ('space', 343),
#  ('remote', 343),
#  ('apart', 342),
#  ('fun!\n', 342),
#  ('quality\n', 341),
#  ('either', 341),
#  ('music', 341),
#  ('job', 341),
#  (':)"\n', 340),
#  ('gift\n', 340),
#  ('"it', 338),
#  ('them!', 338),
#  ('multiple', 336),
#  ('awesome!', 336),
#  ('good.', 336),
#  ('however', 336),
#  ('close', 335),
#  ('regular', 335),
#  ('body', 335),
#  ('20', 334),
#  ('attention', 333),
#  ('set,', 333),
#  ('similar', 332),
#  ('described', 331),
#  ('again.', 330),
#  ('slightly', 330),
#  ('me.', 329),
#  ('display', 328),
#  ('gives', 327),
#  ('themed', 326),
#  ('accessories', 326),
#  ('provided', 326),
#  ('"good', 326),
#  ('busy', 324),
#  ('unique', 324),
#  ('myself', 324),
#  ('fill', 323),
#  ('wife', 323),
#  ('safe', 323),
#  ('believe', 323),
#  ('expensive', 323),
#  ('receive', 322),
#  ('sent', 322),
#  ('base', 322),
#  ('bath', 322),
#  ('barbie', 322),
#  ('tons', 321),
#  ('within', 321),
#  ('brother', 319),
#  ('packaging', 318),
#  ('wrong', 318),
#  ('knew', 318),
#  ('collection.', 318),
#  ('fun\n', 315),
#  ('storage', 315),
#  ('true', 314),
#  ('parents', 314),
#  ('against', 314),
#  ('company', 314),
#  ('toys.', 313),
#  ('problems', 313),
#  ('weeks', 312),
#  ('house.', 312),
#  ('products', 311),
#  ('"excellent', 310),
#  ('it.<br', 309),
#  ('price.\n', 309),
#  ('entire', 309),
#  ('six', 308),
#  ('beach', 308),
#  ('grandsons', 307),
#  ('tool', 307),
#  ('character', 307),
#  ('course', 306),
#  ('gotten', 306),
#  ('all.', 306),
#  ('adorable.', 306),
#  ('time.\n', 305),
#  ('stop', 304),
#  ('spent', 303),
#  ('metal', 303),
#  ('remember', 302),
#  ('monster', 302),
#  ('crazy', 302),
#  ('cannot', 301),
#  ('/>my', 301),
#  ('group', 300),
#  ('/>', 300),
#  ('brought', 299),
#  ('recommended', 299),
#  ('art', 299),
#  ('all,', 298),
#  ('rules', 298),
#  ('mind', 298),
#  ('hat', 297),
#  ('plan', 296),
#  ('colorful', 296),
#  ('comfortable', 296),
#  ('thick', 296),
#  ('expected.\n', 296),
#  ('18', 295),
#  ('size.', 295),
#  ('attached', 295),
#  ('discounted', 294),
#  ('etc.', 294),
#  ('wood', 293),
#  ('great.\n', 293),
#  ('due', 292),
#  ('week', 292),
#  ('else', 292),
#  ('that,', 292),
#  ('turns', 292),
#  ('game\n', 292),
#  ('drone', 291),
#  ('become', 291),
#  ('bed', 290),
#  ('series', 290),
#  ('ride', 290),
#  ('leave', 290),
#  ('decent', 289),
#  ('spend', 289),
#  ('service', 288),
#  ('replacement', 288),
#  ('11', 288),
#  ('box,', 288),
#  ('rest', 288),
#  ('stars', 288),
#  ('giving', 288),
#  ('immediately', 288),
#  ('create', 288),
#  ('allows', 287),
#  ('single', 287),
#  ('cost', 287),
#  ('level', 287),
#  ('one,', 286),
#  ('issues', 286),
#  ('usually', 286),
#  ('cheaper', 285),
#  ('sturdy.', 285),
#  ('truly', 285),
#  ('based', 285),
#  ('1/2', 285),
#  ('quad', 285),
#  ('quality.\n', 285),
#  ('old,', 284),
#  ('bags', 283),
#  ('disney', 283),
#  ('rubber', 283),
#  ('15', 283),
#  ('experience', 282),
#  ('satisfied', 282),
#  ('magic', 281),
#  ('pieces.', 280),
#  ('reading', 279),
#  ('issue', 279),
#  ('standard', 278),
#  ('cake', 278),
#  ('actual', 278),
#  ('!', 277),
#  ('early', 277),
#  ('product!', 277),
#  ('wooden', 276),
#  ('more.', 276),
#  ('challenging', 275),
#  ('coming', 275),
#  ('cut', 275),
#  ('price\n', 275),
#  ('gifts', 274),
#  ('movie', 274),
#  ('grandson.', 274),
#  ('assemble', 274),
#  ('short', 273),
#  ('fun.\n', 273),
#  ('daughter.', 273),
#  ('classic', 272),
#  ('sized', 271),
#  ('princess', 271),
#  ('funko', 271),
#  ('"so', 270),
#  ('son.', 270),
#  ('asked', 270),
#  ('dark', 269),
#  ('roll', 269),
#  ('puzzle.', 269),
#  ('filled', 269),
#  ('legs', 269),
#  ('day.', 269),
#  ('outfit', 268),
#  ('smooth', 268),
#  ('later', 268),
#  ('rc', 267),
#  ('toy.\n', 267),
#  ('point', 266),
#  ('customer', 265),
#  ('name', 265),
#  ('inches', 265),
#  ('colors.', 264),
#  ('product!\n', 263),
#  ('slide', 263),
#  ('beat', 262),
#  ('ago', 262),
#  ("hasn't", 261),
#  ('out,', 261),
#  ('care', 260),
#  ('durable.', 260),
#  ('including', 260),
#  ('understand', 259),
#  ('speed', 259),
#  ('in.', 259),
#  ('clothes', 259),
#  ('also,', 258),
#  ('enjoying', 258),
#  ('glow', 258),
#  ('shape', 257),
#  ('across', 257),
#  (':)', 257),
#  ('educational', 257),
#  ('colored', 257),
#  ('designed', 256),
#  ('toy\n', 256),
#  ('purchasing', 256),
#  ('nice.', 256),
#  ...]

# %%
# list of customer segments
customers = ["son", "daughter", "grandson", "granddaughter", "niece", "nephew", "sibling", "self"]

# %%
# create a dictionary, where keys are customer segments and values are corresponding word count
pos_customer_count = {}
for i in customers:
    pos_customer_count[i] = pos_toy_word_counts[i] + pos_toy_word_counts[i+"s"]

# Change value for sibling (which includes sibling(s), sister(s), and brother(s))
pos_customer_count["sibling"] = pos_toy_word_counts["sibling"] + pos_toy_word_counts["siblings"] + \
pos_toy_word_counts["sister"] + pos_toy_word_counts["sisters"] + pos_toy_word_counts["brother"] + \
pos_toy_word_counts["brothers"]
pos_customer_count
# Out:
# {'daughter': 6381,
#  'granddaughter': 2418,
#  'grandson': 3485,
#  'nephew': 1139,
#  'niece': 995,
#  'self': 107,
#  'sibling': 848,
#  'son': 6224}

# %%
# sort customer_count by value
sort_pos_customer_count = sorted(pos_customer_count.items(), key=operator.itemgetter(1), reverse = True)

# %%
# seperate customer list and their corresponding counts for further plotting
customer_list = [i[0] for i in sort_pos_customer_count]
customer_value = [i[1] for i in sort_pos_customer_count]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Plot customer list and their corresponding counts in a descending order
x_labels = np.arange(len(customer_list))
plt.figure(figsize=(10,5))
plt.bar(x_labels, customer_value, align = "center")
plt.xticks(x_labels, customer_list)
plt.xlabel("Customer Segment")
plt.ylabel("Word Count")
plt.title("Word Count for Customer Segments in Positive Reviews")
for a,b in zip(x_labels, customer_value):
    plt.text(a, b, str(b), horizontalalignment='center', verticalalignment='bottom')
plt.show()

# %% [markdown]
# ### Word Count for Negative Reviews

# %%
# Import positive reviews
neg_review = open("poor_amazon_toy_reviews.txt", "r")

# %%
# read lines
neg_review.seek(0)
lines = neg_review.readlines()

# %%
neg_toy_word_counts = word_counts(lines, " ")

# %%
# sort words and counts in a descending order
sorted(neg_toy_word_counts.items(), key=operator.itemgetter(1), reverse = True)
# Out:
# [('the', 21935),
#  ('and', 11190),
#  ('it', 10486),
#  ('i', 10231),
#  ('to', 9688),
#  ('a', 9414),
#  ('', 7343),
#  ('not', 6793),
#  ('of', 6762),
#  ('this', 5561),
#  ('is', 5505),
#  ('was', 5489),
#  ('for', 4916),
#  ('in', 4248),
#  ('my', 3557),
#  ('with', 3170),
#  ('that', 3045),
#  ('on', 3018),
#  ('but', 3008),
#  ('very', 2674),
#  ('are', 2426),
#  ('they', 2412),
#  ('have', 2265),
#  ('you', 2226),
#  ('as', 2190),
#  ('one', 2158),
#  ('so', 2143),
#  ('be', 1787),
#  ('we', 1742),
#  ('would', 1740),
#  ('had', 1717),
#  ('at', 1688),
#  ('were', 1533),
#  ('all', 1490),
#  ('like', 1490),
#  ('just', 1403),
#  ('when', 1378),
#  ('out', 1312),
#  ('get', 1291),
#  ('only', 1284),
#  ('even', 1277),
#  ('no', 1253),
#  ('these', 1246),
#  ('if', 1221),
#  ('them', 1215),
#  ('from', 1187),
#  ("don't", 1144),
#  ('up', 1137),
#  ('will', 1125),
#  ('or', 1116),
#  ('after', 1111),
#  ('what', 1090),
#  ('do', 1049),
#  ('got', 1039),
#  ('did', 977),
#  ("didn't", 969),
#  ("it's", 962),
#  ('buy', 955),
#  ('product', 951),
#  ('bought', 912),
#  ('your', 890),
#  ('because', 874),
#  ('first', 838),
#  ('off', 829),
#  ('broke', 820),
#  ('waste', 813),
#  ('too', 810),
#  ('it.', 808),
#  ('about', 799),
#  ('than', 793),
#  ('there', 785),
#  ('an', 775),
#  ('received', 722),
#  ('really', 706),
#  ('came', 674),
#  ('time', 672),
#  ('work', 670),
#  ('could', 670),
#  ('disappointed', 668),
#  ('has', 667),
#  ('more', 663),
#  ('/><br', 660),
#  ('2', 653),
#  ('made', 652),
#  ('"i', 652),
#  ('then', 644),
#  ('can', 640),
#  ("doesn't", 626),
#  ('does', 608),
#  ('cheap', 601),
#  ('other', 599),
#  ('use', 598),
#  ('good', 598),
#  ('back', 597),
#  ('two', 595),
#  ('small', 586),
#  ('much', 585),
#  ('money', 584),
#  ('box', 584),
#  ('item', 583),
#  ('old', 582),
#  ('quality', 577),
#  ('put', 574),
#  ('never', 562),
#  ('me', 546),
#  ('return', 536),
#  ('worth', 535),
#  ('way', 532),
#  ('he', 514),
#  ('toy', 513),
#  ('son', 511),
#  ('plastic', 507),
#  ('year', 502),
#  ('pieces', 493),
#  ('some', 487),
#  ('by', 485),
#  ('make', 482),
#  ('before', 478),
#  ("i'm", 475),
#  ('which', 474),
#  ('3', 473),
#  ('-', 471),
#  ('used', 470),
#  ('am', 466),
#  ('ordered', 464),
#  ('also', 462),
#  ('over', 447),
#  ('any', 445),
#  ('kids', 442),
#  ('little', 441),
#  ('should', 441),
#  ('water', 441),
#  ('same', 440),
#  ('now', 440),
#  ('its', 425),
#  ('been', 424),
#  ('piece', 418),
#  ('"this', 411),
#  ('thing', 405),
#  ('our', 399),
#  ('poor', 396),
#  ('his', 395),
#  ('tried', 394),
#  ('look', 394),
#  ('how', 388),
#  ('5', 387),
#  ('looks', 387),
#  ('right', 384),
#  ('fit', 380),
#  ('within', 370),
#  ('into', 366),
#  ('she', 363),
#  ('thought', 361),
#  ('few', 361),
#  ('her', 360),
#  ('battery', 355),
#  ('"the', 352),
#  ('set', 351),
#  ('stay', 349),
#  ('go', 346),
#  ('give', 346),
#  ('still', 346),
#  ('broken', 341),
#  ('bad', 340),
#  ('picture', 339),
#  ('new', 336),
#  ('arrived', 334),
#  ('play', 333),
#  ("can't", 332),
#  ('daughter', 332),
#  ('purchased', 329),
#  ('going', 328),
#  ('it,', 328),
#  ('opened', 324),
#  ('size', 320),
#  ('day', 320),
#  ('another', 319),
#  ('great', 318),
#  ('come', 318),
#  ('1', 315),
#  ('better', 313),
#  ('their', 313),
#  ('returned', 313),
#  ('birthday', 311),
#  ('well', 311),
#  ('game', 310),
#  ('see', 308),
#  ('apart', 308),
#  ('hard', 306),
#  ('something', 301),
#  ("wouldn't", 299),
#  ('know', 298),
#  ('different', 298),
#  ('nothing', 297),
#  ('recommend', 297),
#  ('minutes', 295),
#  ('worked', 295),
#  ('fell', 291),
#  ('want', 289),
#  ('4', 287),
#  ('price', 287),
#  ('took', 286),
#  ('hold', 267),
#  ('work.', 266),
#  ('missing', 266),
#  ('who', 265),
#  ('together', 264),
#  ('batteries', 263),
#  ('half', 263),
#  ('actually', 261),
#  ('big', 259),
#  ('balloons', 258),
#  ('last', 257),
#  ('amazon', 255),
#  ("won't", 253),
#  ('second', 252),
#  ('order', 248),
#  ('think', 246),
#  ('package', 245),
#  ("wasn't", 242),
#  ('went', 239),
#  ('looking', 239),
#  ('cheaply', 238),
#  ('already', 238),
#  ('since', 236),
#  ('product.', 234),
#  ('sure', 233),
#  ('real', 232),
#  ('all.', 232),
#  ('both', 231),
#  ('gift', 230),
#  ('able', 230),
#  ('money.', 228),
#  ('said', 228),
#  ('looked', 227),
#  ('where', 227),
#  ('while', 227),
#  ('buying', 225),
#  ('almost', 222),
#  ('completely', 221),
#  ('enough', 221),
#  ('10', 220),
#  ('reviews', 219),
#  ('them.', 218),
#  ('keep', 217),
#  ('off.', 217),
#  ('purchase', 216),
#  ('open', 214),
#  ('being', 213),
#  ('it.\n', 212),
#  ('most', 212),
#  ('super', 211),
#  ('sent', 211),
#  ('take', 211),
#  ('many', 209),
#  ('wanted', 207),
#  ('down', 207),
#  ('light', 207),
#  ('less', 206),
#  ('around', 206),
#  ('without', 205),
#  ('fun', 205),
#  ('need', 204),
#  ('three', 204),
#  ('working', 204),
#  ('once', 203),
#  ('poorly', 202),
#  ('child', 202),
#  ('excited', 202),
#  ('every', 200),
#  ('terrible', 200),
#  ('says', 199),
#  ('ever', 199),
#  ('disappointed.', 198),
#  ('through', 197),
#  ('send', 197),
#  ('away', 196),
#  ('description', 196),
#  ('find', 196),
#  ('paint', 195),
#  ('parts', 195),
#  ('cards', 194),
#  ('6', 193),
#  ('getting', 192),
#  ('maybe', 192),
#  ('started', 192),
#  ('air', 191),
#  ("couldn't", 190),
#  ('read', 189),
#  ('pretty', 189),
#  ('car', 189),
#  ('&', 189),
#  ('try', 188),
#  ('say', 187),
#  ('days', 184),
#  ('trying', 183),
#  ('extremely', 183),
#  ('smaller', 183),
#  ('top', 181),
#  ('let', 181),
#  ('stopped', 181),
#  ('quality.', 180),
#  ('star', 179),
#  ('tiny', 178),
#  ('figure', 178),
#  ('using', 174),
#  ('long', 172),
#  ('until', 172),
#  ('pay', 172),
#  ('times', 171),
#  ('this.', 170),
#  ('it."\n', 170),
#  ('"very', 170),
#  ('paid', 170),
#  ('supposed', 169),
#  ('definitely', 168),
#  ('several', 168),
#  ('ones', 168),
#  ('returning', 167),
#  ('total', 167),
#  ('each', 166),
#  ('inside', 164),
#  ('/>i', 164),
#  ('anything', 163),
#  ("i've", 163),
#  ('makes', 162),
#  ('love', 160),
#  ('up.', 160),
#  ('replacement', 160),
#  ('loved', 160),
#  ('party', 160),
#  ('instead', 158),
#  ('color', 157),
#  ('wish', 156),
#  ('comes', 156),
#  ('fall', 156),
#  ('horrible', 156),
#  ('toys', 155),
#  ('happy', 154),
#  ('instructions', 154),
#  ('side', 153),
#  ('worst', 153),
#  ('lot', 152),
#  ('gave', 152),
#  ('wrong', 152),
#  ('such', 151),
#  ("that's", 151),
#  ('hours', 150),
#  ('why', 150),
#  ('pool', 150),
#  ('puzzle', 148),
#  ('receive', 147),
#  ('cute', 147),
#  ('complete', 145),
#  ('flimsy', 145),
#  ('ball', 143),
#  ('part', 143),
#  ('played', 142),
#  ('holes', 142),
#  ('.', 141),
#  ('stuck', 141),
#  ('feel', 141),
#  ("isn't", 141),
#  ('hole', 141),
#  ('month', 140),
#  ('playing', 140),
#  ('barely', 139),
#  ('one.', 139),
#  ('again', 139),
#  ('own', 138),
#  ('seller', 138),
#  ('box.', 137),
#  ('bottom', 137),
#  ('doll', 137),
#  ('shipping', 137),
#  ('thin', 137),
#  ('nice', 137),
#  ('found', 136),
#  ('full', 136),
#  ('money.\n', 135),
#  ('out.', 135),
#  ('company', 133),
#  ('red', 133),
#  ('ripped', 133),
#  ('kid', 130),
#  ('junk.', 130),
#  ('kept', 129),
#  ('"these', 129),
#  ('store', 129),
#  ('head', 129),
#  ('turn', 129),
#  ('next', 129),
#  ('original', 128),
#  ('bag', 128),
#  ('easy', 128),
#  ('8', 128),
#  ('difficult', 127),
#  ('brand', 127),
#  ('fill', 127),
#  ('/>the', 127),
#  ('expected', 126),
#  ('huge', 126),
#  ('soon', 126),
#  ('toy.', 124),
#  ('left', 124),
#  ('lasted', 124),
#  ('guess', 124),
#  ('save', 123),
#  ('easily', 123),
#  ('break', 122),
#  ('though', 122),
#  ('week', 122),
#  ('grandson', 121),
#  ('version', 121),
#  ('motor', 121),
#  ('together.', 121),
#  ('things', 120),
#  ('whole', 120),
#  ('people', 120),
#  ('months', 120),
#  ('filled', 120),
#  ('colors', 120),
#  ('everything', 119),
#  ('couple', 119),
#  ('material', 118),
#  ('made.', 118),
#  ('having', 118),
#  ('absolutely', 118),
#  ('it\n', 118),
#  ('balls', 117),
#  ('falling', 117),
#  ('works', 117),
#  ('baby', 117),
#  ('children', 117),
#  ('end', 116),
#  ('dollar', 116),
#  ('under', 116),
#  ('hour', 116),
#  ('ended', 115),
#  ('idea', 115),
#  ('making', 114),
#  ('stand', 114),
#  ('years', 113),
#  ('time.', 113),
#  ('well.', 113),
#  ('unless', 113),
#  ('stars', 112),
#  ('however,', 112),
#  ('him', 112),
#  ('cannot', 112),
#  ('charge', 112),
#  ('card', 112),
#  (',', 111),
#  ('use.', 110),
#  ('30', 110),
#  ('least', 110),
#  ('seems', 110),
#  ('loves', 109),
#  ('dont', 109),
#  ('expensive', 108),
#  ('design', 108),
#  ('rip', 108),
#  ('cost', 108),
#  ('paper', 108),
#  ('"not', 108),
#  ('disappointed.\n', 107),
#  ('on.', 106),
#  ('"it', 106),
#  ('probably', 106),
#  ('packaging', 106),
#  ('black', 105),
#  ('far', 105),
#  ('actual', 105),
#  ('coming', 105),
#  ('weeks', 105),
#  ('wheels', 105),
#  ('balloon', 105),
#  ('longer', 103),
#  ('might', 103),
#  ('hair', 103),
#  ('those', 103),
#  ('"my', 102),
#  ('stickers', 102),
#  ('front', 102),
#  ('popped', 102),
#  ('may', 101),
#  ('high', 101),
#  ('kind', 101),
#  ('slide', 100),
#  ('four', 100),
#  ('cut', 100),
#  ('extra', 100),
#  ('turned', 100),
#  ('broken.', 99),
#  ('sound', 99),
#  ('fly', 99),
#  ('7', 99),
#  ('white', 98),
#  ('again.', 98),
#  ('move', 98),
#  ('items', 97),
#  ('us', 97),
#  ('however', 96),
#  ('back.', 96),
#  ('large', 96),
#  ('pack', 96),
#  ('threw', 96),
#  ('money."\n', 95),
#  ('place', 95),
#  ('someone', 95),
#  ('rubber', 95),
#  ('board', 95),
#  ('spend', 95),
#  ('totally', 94),
#  ('please', 94),
#  ('zero', 93),
#  ('review', 93),
#  ('shown', 92),
#  ('defective', 92),
#  ('putting', 92),
#  ('20', 91),
#  ('close', 91),
#  ('glue', 91),
#  ('throw', 91),
#  ('boat', 91),
#  ('low', 90),
#  ('spent', 90),
#  ('either', 90),
#  ('stick', 89),
#  ('disappointing', 89),
#  ('impossible', 89),
#  ('case', 88),
#  ('12', 88),
#  ('fake', 88),
#  ("you're", 88),
#  ('lost', 87),
#  ('immediately', 86),
#  ('damaged', 86),
#  ('refund', 86),
#  ('run', 86),
#  ('junk', 85),
#  ('needed', 85),
#  ('must', 85),
#  ('clearly', 85),
#  ('anyone', 85),
#  ('picture.', 85),
#  ('problem', 85),
#  ('mine', 84),
#  ('leaked', 84),
#  ('item.', 84),
#  ("son's", 84),
#  ('money\n', 83),
#  ('cheap.', 83),
#  ('others', 83),
#  ('expecting', 83),
#  ('"we', 83),
#  ('pictures', 83),
#  ('always', 83),
#  ('blow', 83),
#  ('falls', 82),
#  ('saw', 82),
#  ('else', 82),
#  ('also,', 82),
#  ('show', 82),
#  ('birthday.', 82),
#  ('shows', 82),
#  ('believe', 80),
#  ('day.', 80),
#  ('small.', 80),
#  ('short', 80),
#  ('lights', 80),
#  ('rather', 79),
#  ('directions', 79),
#  ("they're", 79),
#  ('upon', 79),
#  ('legs', 79),
#  ('replace', 79),
#  ('here', 79),
#  ('customer', 79),
#  ('kit', 79),
#  ('feet', 79),
#  ('advertised', 78),
#  ('single', 78),
#  ('none', 78),
#  ('tell', 78),
#  ('entire', 78),
#  ('five', 78),
#  ('fix', 77),
#  ('remote', 77),
#  ("i'd", 77),
#  ('up,', 76),
#  ('bubbles', 76),
#  ('today', 76),
#  ('work,', 76),
#  ('upset', 76),
#  ('given', 76),
#  ('water.', 76),
#  ('disappointed."\n', 76),
#  ('15', 75),
#  ('cover', 75),
#  ('screws', 75),
#  ('power', 75),
#  ('face', 75),
#  ('product,', 75),
#  ('pop', 74),
#  ('finally', 74),
#  ('opening', 74),
#  ('bit', 74),
#  ('basically', 74),
#  ('inch', 73),
#  ('unfortunately', 73),
#  ('expect', 73),
#  ('figures', 73),
#  ('loose', 72),
#  ('all,', 72),
#  ('best', 72),
#  ('unable', 72),
#  (':(\n', 72),
#  ('arm', 72),
#  ('useless', 72),
#  ('blue', 72),
#  ('rest', 72),
#  ('fine', 71),
#  ('thinking', 71),
#  ("aren't", 71),
#  ('hot', 71),
#  ('pieces.', 71),
#  ('noticed', 71),
#  ('off,', 71),
#  ('later', 71),
#  ('gun', 70),
#  ('this,', 70),
#  ('itself', 70),
#  ('build', 70),
#  ('clear', 70),
#  ('away.', 70),
#  ('reason', 70),
#  ('product.\n', 70),
#  ('due', 69),
#  ('terrible.', 69),
#  ('box,', 69),
#  ('gets', 69),
#  ('cheap,', 69),
#  ('money,', 69),
#  ('charged', 69),
#  ('deflated', 69),
#  ('sets', 68),
#  ('cool', 68),
#  ('control', 68),
#  ('minutes.', 68),
#  ('product."\n', 68),
#  ('decided', 68),
#  ('hand', 68),
#  ('inches', 68),
#  ("there's", 68),
#  ('during', 68),
#  ('metal', 68),
#  ('change', 68),
#  ('help', 67),
#  ('smell', 67),
#  ('quite', 67),
#  ('green', 67),
#  ('start', 67),
#  ('handle', 67),
#  ('sticker', 67),
#  ('matter', 67),
#  ('charger', 66),
#  ('"bought', 66),
#  ('quality,', 66),
#  ('twice', 66),
#  ('lego', 66),
#  ('again."\n', 66),
#  ('button', 66),
#  ('straight', 66),
#  ('motors', 66),
#  ('pull', 66),
#  ('properly', 65),
#  ('called', 65),
#  ('goes', 65),
#  ('told', 65),
#  ('seemed', 65),
#  ('needs', 65),
#  ('regular', 64),
#  ('"if', 64),
#  ('screw', 64),
#  ('wasted', 64),
#  ('cracked', 64),
#  ('wheel', 64),
#  ('past', 64),
#  ('again.\n', 64),
#  ('truck', 64),
#  ('literally', 64),
#  ('cars', 64),
#  ('products', 63),
#  ('model', 63),
#  ('taking', 63),
#  ('plus', 63),
#  ('didnt', 63),
#  ('point', 63),
#  ('quickly', 63),
#  ('bubble', 63),
#  ('apart.', 63),
#  ('old.', 63),
#  ('multiple', 63),
#  ('--', 62),
#  ('purchasing', 62),
#  ('house', 62),
#  ('stop', 62),
#  ('cheaper', 61),
#  ('granddaughter', 61),
#  ('hands', 61),
#  ('well,', 61),
#  ('disappointed\n', 61),
#  ('inflated', 61),
#  ('price.', 61),
#  ('flat', 61),
#  ('float', 61),
#  ('plastic.', 61),
#  ("i'll", 61),
#  ('seam', 61),
#  ('worked.', 60),
#  ('package.', 60),
#  ('match', 60),
#  ('christmas', 60),
#  ('sticks', 60),
#  ('normal', 60),
#  ('line', 60),
#  ('adult', 60),
#  ('expected.', 60),
#  ('wood', 59),
#  ('glow', 59),
#  ('costume', 59),
#  ('exactly', 59),
#  ('tube', 59),
#  ('pulled', 58),
#  ('disappointment', 58),
#  ('broke.', 58),
#  ('photo', 58),
#  ('stuff', 58),
#  ('felt', 58),
#  ('wear', 58),
#  ('attached', 58),
#  ('me.', 58),
#  ('simply', 58),
#  ('seen', 58),
#  ('wait', 58),
#  ('packs', 57),
#  ('included', 57),
#  ('small\n', 57),
#  ('days.', 57),
#  ('especially', 57),
#  ('work.\n', 57),
#  ('hit', 57),
#  ('seem', 57),
#  ('push', 57),
#  ('garbage', 57),
#  ('out,', 57),
#  ('husband', 56),
#  ('ok', 56),
#  ('hoping', 56),
#  ('tape', 56),
#  ('them.\n', 56),
#  ('outside', 55),
#  ('"do', 55),
#  ('fact', 55),
#  ('9', 55),
#  ('sounds', 55),
#  ('strong', 55),
#  ('replaced', 55),
#  ('these.', 55),
#  ("daughter's", 55),
#  ('meant', 54),
#  ('them,', 54),
#  ('larger', 54),
#  ('train', 54),
#  ('x', 54),
#  ('unit', 54),
#  ('hate', 54),
#  ('leak', 54),
#  ('one,', 54),
#  ('pink', 54),
#  ('add', 54),
#  ('flew', 53),
#  ('refund.', 53),
#  ('heavy', 53),
#  ('plane', 53),
#  ('garbage.', 53),
#  ('easily.', 53),
#  ('quality.\n', 53),
#  ('takes', 53),
#  ('"don\'t', 52),
#  ('dog', 52),
#  ('time,', 52),
#  ('sending', 52),
#  ('string', 52),
#  ('hardly', 52),
#  ('awful', 52),
#  ('yet', 52),
#  ('in.', 52),
#  ('between', 52),
#  ('sit', 51),
#  ('trash', 51),
#  ('it!', 51),
#  ('quality\n', 51),
#  ('kids.', 51),
#  ('flight', 51),
#  ('pictured', 51),
#  ('horrible.', 51),
#  ('sitting', 51),
#  ('knock', 51),
#  ('asked', 51),
#  ('bunch', 51),
#  ('feels', 51),
#  ('bigger', 51),
#  ('24', 51),
#  ('work\n', 51),
#  ('cardboard', 51),
#  ('third', 51),
#  ('working.', 51),
#  ('charging', 51),
#  ('ago', 51),
#  ('rc', 51),
#  ('arms', 51),
#  ('forward', 51),
#  ('showed', 50),
#  ('chinese', 50),
#  ('nearly', 50),
#  ('late', 50),
#  ('flying', 50),
#  ('understand', 50),
#  ('amount', 50),
#  ('batteries,', 50),
#  ('sell', 50),
#  ('held', 50),
#  ('tail', 50),
#  ('fast', 49),
#  ('made,', 49),
#  ('designed', 49),
#  ('free', 49),
#  ('u', 49),
#  ('ordering', 49),
#  ('2nd', 49),
#  ('breaks', 49),
#  ('home', 49),
#  ('remove', 49),
#  ('glued', 49),
#  ('number', 49),
#  ('near', 49),
#  ('issue', 49),
#  ('six', 49),
#  ('giving', 49),
#  ('hope', 49),
#  ('buyer', 49),
#  ('fabric', 49),
#  ('assembly', 49),
#  ('seams', 49),
#  ('girl', 49),
#  ('realize', 49),
#  ('followed', 48),
#  ('china', 48),
#  ('small,', 48),
#  ('game.', 48),
#  ('sons', 48),
#  ('sad', 48),
#  ('bent', 48),
#  ('everyone', 48),
#  ('lots', 48),
#  ('all.\n', 48),
#  ('drone', 48),
#  ('service', 48),
#  ('party.', 48),
#  ('pick', 47),
#  ('yr', 47),
#  ('ring', 47),
#  ('similar', 47),
#  ('doing', 47),
#  ('frustrating', 47),
#  ('usually', 47),
#  ('manufacturer', 47),
#  ('games', 47),
#  ('shipped', 47),
#  ('on,', 47),
#  ('minute', 47),
#  ('store.', 47),
#  ('except', 47),
#  ('liked', 47),
#  ('false', 46),
#  ('crap.', 46),
#  ('done', 46),
#  ('hat', 46),
#  ('dress', 46),
#  ('leg', 46),
#  ('young', 46),
#  ('crap', 46),
#  ('0', 46),
#  ('together,', 46),
#  ('week.', 46),
#  ('waiting', 45),
#  ('this.\n', 45),
#  ('cause', 45),
#  ('against', 45),
#  ('correct', 45),
#  ('contact', 45),
#  ('described', 45),
#  ('for.', 45),
#  ('(and', 45),
#  ('delivered', 45),
#  ("haven't", 45),
#  ('(the', 45),
#  ('base', 44),
#  ('eyes', 44),
#  ('worse', 44),
#  ('exact', 44),
#  ('keeps', 44),
#  ('cube', 44),
#  ('placed', 44),
#  ('phone', 44),
#  ('blew', 44),
#  ('book', 44),
#  ('tore', 44),
#  ('obviously', 44),
#  ('along', 44),
#  ('gift.', 44),
#  ('sold', 44),
#  ('zipper', 44),
#  ("weren't", 44),
#  ('not.', 44),
#  ('amazon.', 44),
#  ('experience', 44),
#  ('present', 43),
#  ('purchase.', 43),
#  ('reading', 43),
#  ('cant', 43),
#  ('seconds', 43),
#  ('dollars', 43),
#  ('leaks', 43),
#  ('although', 43),
#  ('disappointed,', 43),
#  ('(which', 43),
#  ('live', 43),
#  ('weight', 43),
#  ('onto', 43),
#  ('use.\n', 43),
#  ('dead', 43),
#  ('pictured.', 43),
#  ('mini', 43),
#  ('awful.', 43),
#  ('toy,', 43),
#  ('disappointing.\n', 42),
#  ('person', 42),
#  ('wings', 42),
#  ('stupid', 42),
#  ('post', 42),
#  ('ship', 42),
#  ('local', 42),
#  ('buy.', 42),
#  ('check', 42),
#  ('family', 42),
#  ('dried', 42),
#  ('china.', 42),
#  ('online', 42),
#  ('job', 42),
#  ('snapped', 42),
#  ('turns', 42),
#  ('leave', 41),
#  ('would.', 41),
#  ('based', 41),
#  ('mention', 41),
#  ('use,', 41),
#  ('touch', 41),
#  ('plastic,', 41),
#  ('avoid', 41),
#  ('sturdy', 41),
#  ('immediately.', 41),
#  ('switch', 41),
#  ('realized', 41),
#  ('taped', 41),
#  ('/>this', 41),
#  ('"they', 41),
#  ('video', 41),
#  ('removed', 41),
#  ('good.', 41),
#  ('reviews.', 41),
#  ('support', 41),
#  ('fits', 41),
#  ('wire', 41),
#  ('fire', 41),
#  ('toys.', 41),
#  ('body', 41),
#  ('older', 40),
#  ('frustrated', 40),
#  ('pen', 40),
#  ('nerf', 40),
#  ('connect', 40),
#  ('description.', 40),
#  ('either.', 40),
#  ('painted', 40),
#  ('unfortunately,', 40),
#  ('animal', 40),
#  ('name', 40),
#  ...]

# %%
# list of customer segments
customers = ["son", "daughter", "grandson", "granddaughter", "niece", "nephew", "sibling", "self"]

# %%
# create a dictionary, where keys are customer segments and values are corresponding word count
neg_customer_count = {}
for i in customers:
    neg_customer_count[i] = neg_toy_word_counts[i] + neg_toy_word_counts[i+"s"]

# Change value for sibling (which includes sibling(s), sister(s), and brother(s))
neg_customer_count["sibling"] = neg_toy_word_counts["sibling"] + neg_toy_word_counts["siblings"] + \
neg_toy_word_counts["sister"] + neg_toy_word_counts["sisters"] + neg_toy_word_counts["brother"] + \
neg_toy_word_counts["brothers"]
neg_customer_count
# Out:
# {'daughter': 371,
#  'granddaughter': 70,
#  'grandson': 145,
#  'nephew': 32,
#  'niece': 35,
#  'self': 20,
#  'sibling': 38,
#  'son': 559}

# %%
# sort customer_count by value
sort_neg_customer_count = sorted(neg_customer_count.items(), key=operator.itemgetter(1), reverse = True)

# %%
# seperate customer list and their corresponding counts for further plotting
customer_list = [i[0] for i in sort_neg_customer_count]
customer_value = [i[1] for i in sort_neg_customer_count]

# %%
# Plot customer list and their corresponding counts in a descending order
x_labels = np.arange(len(customer_list))
plt.figure(figsize=(10,5))
plt.bar(x_labels, customer_value, align = "center")
plt.xticks(x_labels, customer_list)
plt.xlabel("Customer Segment")
plt.ylabel("Word Count")
plt.title("Word Count for Customer Segments in Negative Reviews")
for a,b in zip(x_labels, customer_value):
    plt.text(a, b, str(b), horizontalalignment='center', verticalalignment='bottom')
plt.show()

# %% [markdown]
# ### "Sales" Approach

# %%
# count of customer segments in positive and negative reviews
print(pos_customer_count)
print(neg_customer_count)
# Out:
# {'son': 6224, 'daughter': 6381, 'grandson': 3485, 'granddaughter': 2418, 'niece': 995, 'nephew': 1139, 'sibling': 848, 'self': 107}
# {'son': 559, 'daughter': 371, 'grandson': 145, 'granddaughter': 70, 'niece': 35, 'nephew': 32, 'sibling': 38, 'self': 20}

# %%
# sales for each customer segment
sales = {}
for i in pos_customer_count.keys():
    sales[i] = pos_customer_count[i] + neg_customer_count[i]
sales
# Out:
# {'daughter': 6752,
#  'granddaughter': 2488,
#  'grandson': 3630,
#  'nephew': 1171,
#  'niece': 1030,
#  'self': 127,
#  'sibling': 886,
#  'son': 6783}

# %% [markdown]
# ### "Average Stars" Approach

# %%
# count of customer segments in positive and negative reviews
print(pos_customer_count)
print(neg_customer_count)
# Out:
# {'son': 6224, 'daughter': 6381, 'grandson': 3485, 'granddaughter': 2418, 'niece': 995, 'nephew': 1139, 'sibling': 848, 'self': 107}
# {'son': 559, 'daughter': 371, 'grandson': 145, 'granddaughter': 70, 'niece': 35, 'nephew': 32, 'sibling': 38, 'self': 20}

# %%
# average review star for each customer segment
# 5 star for positive review; 1 star for negative review
average_star = {}
for i in pos_customer_count.keys():
    average_star[i] = round((5 * pos_customer_count[i] + neg_customer_count[i]) / \
                            (pos_customer_count[i] + neg_customer_count[i]),3)
average_star
# Out:
# {'daughter': 4.78,
#  'granddaughter': 4.887,
#  'grandson': 4.84,
#  'nephew': 4.891,
#  'niece': 4.864,
#  'self': 4.37,
#  'sibling': 4.828,
#  'son': 4.67}

# %% [markdown]
# ### Battery

# %%
# word count of battery (battery and batteries) for positive and negative reviews
pos_battery_count = pos_toy_word_counts["battery"] + pos_toy_word_counts["batteries"]
neg_battery_count = neg_toy_word_counts["battery"] + neg_toy_word_counts["batteries"]

# %%
# Get total number of reviews for positive and negative reviews
pos_review.seek(0)
pos_lines = pos_review.readlines()
pos_total = len(pos_lines)

neg_review.seek(0)
neg_lines = neg_review.readlines()
neg_total = len(neg_lines)

# %%
# For the rest reviews that do not mention whether the toy requires battery, 
# assume a percentage of reviews with battery for further analysis
battery_per = np.linspace(0, 0.999, 100)

# %%
# Total count of battery for positive and negative reviews
pos_battery = pos_battery_count + battery_per * (pos_total - pos_battery_count)
neg_battery = neg_battery_count + battery_per * (neg_total - neg_battery_count)

# %%
# Total count of toys without battery for positive and negative reviews
pos_no_battery = pos_total - pos_battery
neg_no_battery = neg_total - neg_battery

# %%
# Average review star for toys with and without battery
ba_average = (5* pos_battery + neg_battery) / (pos_battery + neg_battery)
no_ba_average = (5 * pos_no_battery + neg_no_battery) / (pos_no_battery + neg_no_battery)

# %%
# Define a significant level. Assume that if the average review for toys with battery is lower than 
# 95% of average review for toys without battery, then they have significant difference
significant_per = 0.95

# %%
# Plot average review for toys with and without battery
# Also plot the threshold for determining whether they have significant difference
plt.figure(figsize=(15,7))
plt.plot(battery_per, ba_average, label = "average review star for toys with battery")
plt.plot(battery_per, no_ba_average, label = "average review star for toys without battery")
plt.xticks(np.arange(min(battery_per), max(battery_per) + 0.05, 0.05))
plt.axhline(significant_per* no_ba_average[0], color = "g", linestyle = "--", label = "threshold line")
plt.xlabel("Percentage of Battery Reviews")
plt.ylabel("Average Review Star")
plt.title("Average Reviews for Toys with and without Battery")
plt.legend()
plt.show()
